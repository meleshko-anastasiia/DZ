# %%
import pandas as pd
import numpy as np

# %%
df_car = pd.read_excel(r"/Users/a.meleshko/Documents/GitHub/DZ/Car Price2.xlsx")

# %%
df_car
# Out:
#             Brand                                     Model  Year  \
# 0          Maruti                             Maruti 800 AC  2007
# 1         Hyundai                      Hyundai Verna 1.6 SX  2012
# 2          Datsun                    Datsun RediGO T Option  2017
# 3           Honda                     Honda Amaze VX i-DTEC  2014
# 4         Hyundai                 Hyundai Xcent 1.2 Kappa S  2016
# 5         Hyundai                  Hyundai Creta 1.6 VTVT S  2015
# 6          Toyota           Toyota Corolla Altis 1.8 VL CVT  2018
# 7         Hyundai               Hyundai Venue SX Opt Diesel  2019
# 8       Chevrolet         Chevrolet Enjoy TCDi LTZ 7 Seater  2013
# 9            Audi                           Audi Q5 2.0 TDI  2011
# 10  Mercedes-Benz  Mercedes-Benz E-Class E 200 CGI Elegance  2010
# 11           Audi            Audi Q7 35 TDI Quattro Premium  2009
# 12         Maruti                           Maruti Alto LXi  2006
# ...

# %%
long_data_car = df_car.copy()
long_data_car.set_index(['Year', 'Fuel'], drop = True, inplace = True)

# %%
long_data_car
# Out:
#                      Brand                                     Model  \
# Year Fuel
# 2007 Petrol         Maruti                             Maruti 800 AC
# 2012 Diesel        Hyundai                      Hyundai Verna 1.6 SX
# 2017 Petrol         Datsun                    Datsun RediGO T Option
# 2014 Diesel          Honda                     Honda Amaze VX i-DTEC
# 2016 Petrol        Hyundai                 Hyundai Xcent 1.2 Kappa S
# 2015 Petrol        Hyundai                  Hyundai Creta 1.6 VTVT S
# 2018 Petrol         Toyota           Toyota Corolla Altis 1.8 VL CVT
# 2019 Diesel        Hyundai               Hyundai Venue SX Opt Diesel
# 2013 Diesel      Chevrolet         Chevrolet Enjoy TCDi LTZ 7 Seater
# 2011 Diesel           Audi                           Audi Q5 2.0 TDI
# 2010 Petrol  Mercedes-Benz  Mercedes-Benz E-Class E 200 CGI Elegance
# 2009 Diesel           Audi            Audi Q7 35 TDI Quattro Premium
# ...

# %%
wide_data_car = long_data_car.unstack()

# %%
wide_data_car
# Out:
#           Brand                                             Model  \
# Fuel     Diesel         Petrol                             Diesel
# Year
# 1992        NaN         Maruti                                NaN
# 1995        NaN         Maruti                                NaN
# 1996   Mahindra            NaN           Mahindra Jeep CL 500 MDI
# 1997   Mahindra            NaN           Mahindra Jeep CL 500 MDI
# 1998        NaN         Maruti                                NaN
# 1999        NaN        Hyundai                                NaN
# 2000        NaN         Maruti                                NaN
# 2001        NaN         Maruti                                NaN
# 2002        NaN        Hyundai                                NaN
# 2003        NaN        Hyundai                                NaN
# 2004        NaN         Maruti                                NaN
# 2005       Tata            NaN                    Tata Indica DLS
# ...

# %%
df_car.pivot(index = 'Year', columns = 'Brand', values = 'Selling_Price')
# Out:
# Brand       Audi  Chevrolet    Datsun     Honda    Hyundai  Mahindra  \
# Year
# 1992         NaN        NaN       NaN       NaN        NaN       NaN
# 1995         NaN        NaN       NaN       NaN        NaN       NaN
# 1996         NaN        NaN       NaN       NaN        NaN  250000.0
# 1997         NaN        NaN       NaN       NaN        NaN  150000.0
# 1998         NaN        NaN       NaN       NaN        NaN       NaN
# 1999         NaN        NaN       NaN       NaN    50000.0       NaN
# 2000         NaN        NaN       NaN       NaN        NaN       NaN
# 2001         NaN        NaN       NaN       NaN        NaN       NaN
# 2002         NaN        NaN       NaN       NaN    65000.0       NaN
# 2003         NaN        NaN       NaN       NaN    75000.0       NaN
# 2004         NaN        NaN       NaN       NaN        NaN       NaN
# 2005         NaN        NaN       NaN       NaN        NaN       NaN
# ...

# %%
wide_data_car = long_data_car.unstack()
wide_data_car.columns = ['Petrol', 'Diesel']
wide_data_car
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 2
#       1 wide_data_car = long_data_car.unstack()
# ----> 2 wide_data_car.columns = ['Petrol', 'Diesel']
#       3 wide_data_car
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
# ...
