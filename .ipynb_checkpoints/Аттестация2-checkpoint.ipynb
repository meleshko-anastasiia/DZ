# %%
from multidict import MultiDict
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/meleshko-anastasiia/DZ/refs/heads/main/Computers.csv")
df
# Out:
#       rownames  price  speed    hd  ram  screen   cd multi premium  ads  trend
# 0            1   1499     25    80    4      14   no    no     yes   94      1
# 1            2   1795     33    85    2      14   no    no     yes   94      1
# 2            3   1595     25   170    4      15   no    no     yes   94      1
# 3            4   1849     25   170    8      14   no    no      no   94      1
# 4            5   3295     33   340   16      14   no    no     yes   94      1
# ...        ...    ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254      6255   1690    100   528    8      15   no    no     yes   39     35
# 6255      6256   2223     66   850   16      15  yes   yes     yes   39     35
# 6256      6257   2654    100  1200   24      15  yes    no     yes   39     35
# 6257      6258   2195    100   850   16      15  yes    no     yes   39     35
# 6258      6259   2490    100   850   16      17  yes    no     yes   39     35
#
# [6259 rows x 11 columns]

# %%
#2.Сформулируйте на базе переменных три вида гипотез

# %%
#Анализ на основе данных:
#Характеристик : цена, скорость, hd, оперативная память, экран, cd, мульти, премиум,реклама и тренд
#Цель : цена = f(скорость, hd, оперативная память, экран, cd, мульти, премиум, реклама, тренд)
#Категориальные функции с уровнями "да" и "нет" - cd, multi, premium .

# %%
#Какие переменные будем использовать
sns.pairplot(df[["price", "premium", "ram", "multi", "speed", "hd", "screen", "cd", "ads", "trend"]])

# %%
p=sns.pairplot(df, hue = 'cd')

# %%
#b)Выберите одну категориальную и одну числовую переменную и сформулируйте гипотезу об их взаимосвязи
#гипотеза о взаимосвязи цены и сегмента premium

# %%
df1 = df.loc[df['premium']=='yes', 'price']
df2 = df.loc[df['premium']=='no', 'price']
fig = plt.figure()
plt.title('Распределение цены премиум сегмента')
sns.histplot(df1[df1<5000], kde = True)
plt.show()

# %%
# Тест Шапиро-Уилка
stats.shapiro(df1[df1<5000])
# Out:
# ShapiroResult(statistic=0.9728935956954956, pvalue=2.082402113315022e-31)

# %%
#p-значение очень маленькое, т.е. нулевая гипотеза отвергается и распределение нельзя считать нормальным

# %%
#a)Выберите две категориальные переменные и сформулируйте гипотезу об их взаимосвязи
#гипотеза о взаимосвязи multy(мультимидийности) и premium сегмента

# %%
# создадим grouped countplot, где по оси x будет премиум, а по оси y - мультимедийность
sns.countplot(x = 'premium', hue = 'multi', data = df);

# %%
#Добавим еще признак cd

# %%
sns.catplot(x = 'premium', hue = 'multi', col = 'cd', kind = 'count', data = df);

# %%
#cd есть там, где есть мультимедийность

# %%
contingency_table = pd.crosstab(df['multi'], df['premium'])
print(contingency_table)
# Out:
# premium   no   yes
# multi
# no       607  4779
# yes        5   868

# %%
#Больше всего в премиум сегменте немультимедийных комплектов

# %%
# Нулевая гипотеза chi2_contingency - не о нормальности распределения, а о взаимосвязи двух категориальных переменных!
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"χ²: {chi2}, p-значение: {p}")
# Out:
# χ²: 96.2359080049412, p-значение: 1.0197844937426662e-22

# %%
##p-значение очень маленькое, т.е. нулевая гипотеза отвергается и распределение нельзя считать нормальным

# %%
#c)Выберите две числовые переменные и сформулируйте гипотезу об их взаимосвязи
#Сначала ram, price ads

# %%
sns.lmplot(
    data = df[(df['ads']>0)&(df['price']>0)&(df['ram']>=16)], 
    x = 'ads', 
    y = 'price', 
    hue = 'ram'
)
plt.show()

# %%
#По графику предпологаем, что чем больше рекламы, тем выше цена
#Коэфициент корреляции положителен =1

# %%
sns.scatterplot(data = df, x = 'ads', y = 'trend')
# Out:
# <Axes: xlabel='ads', ylabel='trend'>

# %%
# Тест Шапиро-Уилка
stats.shapiro(df1[df1<5000])
# Out:
# ShapiroResult(statistic=0.9478679299354553, pvalue=1.877739942195255e-42)

# %%
stats.kstest(df1[df1<5000], stats.norm.cdf)
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=949, statistic_sign=-1)

# %%
#р-значение является очень низким, т.е. нулевая гипотеза отвергается. Распределение не является нормальным

# %%
#Сравним еще значения speed and ram
#скорость работы компьютеров увеличивается с увеличением объема оперативной памяти.

# %%
sns.lmplot(
    data = df[(df['price']<=5000)&(df['price']>0)&(df['ram']<30)], 
    x = 'price', 
    y = 'speed', 
    hue = 'ram'
)
plt.show()

# %%
#как мы и ожидали, чем больше оперативной памяти, тем выше будет цена.

# %%
#3.Для каждой гипотезы постарайтесь привести логический смысл, почему вы считаете, что эта взаимосвязь должна существовать и какую форму 
#взаимосвязи вы ожидаете. Что это дает с практической точки зрения?
#Пояснения также после гипотез

# %%
#4.Для выбранных переменных проведите разведочный анализ данных. Приведите наиболее подходящие описательные статистики, частотные распределения,
#постройте графики, которые бы давали представление как о переменных по отдельности, так и об их взаимосвязи
#Графики построены под гипотезами

# %%
# 5. Проведите очистку данных от пропусков, выбросов и некорректных значений любым выбранным способом. Постарайтесь обосновать этот способ

# %%
df.isna().sum()
# Out:
# rownames    0
# price       0
# speed       0
# hd          0
# ram         0
# screen      0
# cd          0
# multi       0
# premium     0
# ads         0
# trend       0
# dtype: int64

# %%
#пропущенных значений нет.

# %%
df.describe()
# Out:
#              price        speed           hd          ram       screen  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   2219.576610    52.011024   416.601694     8.286947    14.608723
# std     580.803956    21.157735   258.548445     5.631099     0.905115
# min     949.000000    25.000000    80.000000     2.000000    14.000000
# 25%    1794.000000    33.000000   214.000000     4.000000    14.000000
# 50%    2144.000000    50.000000   340.000000     8.000000    14.000000
# 75%    2595.000000    66.000000   528.000000     8.000000    15.000000
# max    5399.000000   100.000000  2100.000000    32.000000    17.000000
#
#                ads        trend
# count  6259.000000  6259.000000
# mean    221.301007    15.926985
# std      74.835284     7.873984
# min      39.000000     1.000000
# 25%     162.500000    10.000000
# 50%     246.000000    16.000000
# 75%     275.000000    21.500000
# max     339.000000    35.000000

# %%
df['price'].hist(bins = 300)
# Out:
# <Axes: >

# %%
#На данном графике выбросы видно не очень хорошо, поэтому используем другой

# %%
import seaborn as sns
sns.boxplot(df['price'])
# Out:
# <Axes: >

# %%
#На приведенном выше графике хорошо видно, что значения выше 4000 действуют как выбросы. 
#Boxplot обобщает выборочные данные с использованием 25-го, 50-го и 75-го процентилей.
#Можно просто получить представление (квартили, медиану и выбросы) о наборе данных, просто взглянув на его блок-схему

# %%
#Построение «ящика с усами» , чтобы получить представление до и после удаления выбросов 
def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()

    removed_outliers = df[df[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers


threshold_value = 3790

no_outliers = removal_box_plot(df, 'price', threshold_value)

# %%
#Будем считать что выбросы находятся за пределами значений 3750 и 1000
df[(df['price']<=3750)|(df['price']>=1000)]
# Out:
#       price  speed    hd  ram  screen   cd multi premium  ads  trend  \
# 0      1499     25    80    4      14   no    no     yes   94      1
# 1      1795     33    85    2      14   no    no     yes   94      1
# 2      1595     25   170    4      15   no    no     yes   94      1
# 3      1849     25   170    8      14   no    no      no   94      1
# 4      3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254   1690    100   528    8      15   no    no     yes   39     35
# 6255   2223     66   850   16      15  yes   yes     yes   39     35
# 6256   2654    100  1200   24      15  yes    no     yes   39     35
# 6257   2195    100   850   16      15  yes    no     yes   39     35
# 6258   2490    100   850   16      17  yes    no     yes   39     35
#
#      multi_adj segment
# 0         more     NaN
# 1         more     NaN
# 2         more     NaN
# 3         more     NaN
# 4         more     NaN
# ...        ...     ...
# 6254      more     NaN
# 6255      more     NaN
# 6256      more     NaN
# 6257      more     NaN
# 6258      more     NaN
#
# [6259 rows x 12 columns]

# %%
prices = df.price #Извлечение столбца цен
prices.head(10) # Вывод первых 10 значений
# Out:
# 0    1499
# 1    1795
# 2    1595
# 3    1849
# 4    3295
# 5    3695
# 6    1720
# 7    1995
# 8    2225
# 9    2575
# Name: price, dtype: int64

# %%
# Lets plot a histogram to see if our data is normally distributed
fig= plt.subplots(figsize=(15, 10))data
plt.xticks()
plt.yticks()
plt.title("Histogram of data")
plt.xlabel("Price")
plt.ylabel("Number")
plt.hist(prices)
plt.show()

# %%
#Кажется, что данные больше смещены влево. 
#Причина, по которой данные смещены влево, заключается в том, что большая часть цен на компьютеры приходится на 2000-е годы, в то время как максимальная
#5000-е годы. Это приводит к неравномерному распределению в наборе данных.

# %%
#6.Протестируйте распределение числовой переменной на соответствие нормальному. Постройте QQ-plot и гистограмму

# %%
df1 = df.loc[df['premium']=='yes', 'price']
df2 = df.loc[df['premium']=='no', 'price']

# %%
fig = plt.figure()
plt.title('Распределение стоимости премиум сегмента')
sns.histplot(df1[df1<5000], kde = True)
plt.show()

# %%
df1 = df.loc[(df['premium']=='yes')&(df['price']<5000), 'price']
df2 = df.loc[(df['premium']=='no')&(df['price']<5000), 'price']

# %%
fig, ax  = plt.subplots(1,2, figsize = (15,5))
plt.suptitle('Распределение стоимости премиум сегмента и нет')
sns.histplot(df1, kde = True, ax = ax[0])
sns.histplot(df2, kde = True, ax = ax[1])
plt.show()

# %%
#В не премиальном сегменте существуют модели схожие по цене с премиальным сегментом

# %%
print('Средняя: ', df1.mean())
print('Медиана: ', df1.median())
print('Скошенность: ', stats.skew(df1))
print('Эксцесс: ', stats.kurtosis(df1))
# Out:
# Средняя:  2202.4502126151665
# Медиана:  2143.5
# Скошенность:  0.6302556021872963
# Эксцесс:  0.4267092343250445

# %%
print('Средняя: ', df2.mean())
print('Медиана: ', df2.median())
print('Скошенность: ', stats.skew(df2))
print('Эксцесс: ', stats.kurtosis(df2))
# Out:
# Средняя:  2361.9346405228757
# Медиана:  2249.0
# Скошенность:  0.6594366634993016
# Эксцесс:  -0.1739594664079398

# %%
fig, ax  = plt.subplots(1,2, figsize = (15,5))
plt.title('QQ-plot')
stats.probplot(df1, dist="norm", plot = ax[0])
stats.probplot(df2, dist="norm", plot = ax[1])
plt.show()

# %%
# Тест Шапиро-Уилка
stats.shapiro(df1[df1<5000])
# Out:
# ShapiroResult(statistic=0.9728935956954956, pvalue=2.082402113315022e-31)

# %%
#p-значение очень маленькое, т.е. нулевая гипотеза отвергается и распределение нельзя считать нормальным

# %%
#7.Проведите тесты гипотез из пункта (2) и сделайте выводы. Какой практический смысл имеют результаты проведенных тестов? Каких можно использовать?

# %%
df1_price = df.loc[(df['premium']=='yes')&(df['ram']<100)&(df['price']<5000), 'price']
df2_price = df.loc[(df['premium']=='no')&(df['ram']<100)&(df['price']<5000), 'price']

# %%
print('Средняя цена премиум сегмента с памятью менее 100 составляет', df1_price.mean().round(2))
# Out:
# Средняя цена премиум сегмента с памятью менее 100 составляет 2202.45

# %%
print('Средняя цена не премиум сегмента с памятью менее 100 составляет', df2_price.mean().round(2))
# Out:
# Средняя цена не премиум сегмента с памятью менее 100 составляет 2361.93

# %%
#Протестируем гипотезу о том, что математическое ожидание цены премиум сегмента составляет 2300

# %%
stats.ttest_1samp(df1_price, popmean = 2300, alternative = 'two-sided')
# Out:
# TtestResult(statistic=-12.952164002572848, pvalue=7.871657561756482e-38, df=5643)

# %%
#p-значение более 5%, то есть нулевую гипотезу отвергнуть нельзя
#Средняя цена премиум сегмента может составлять 2300

# %%
#На практике это поможет определить, что можно приобрести в премиум сегменте за 2300 компьютер с разной памятью
